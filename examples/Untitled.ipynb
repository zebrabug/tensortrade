# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import glob, os
import sys
sys.path.append("../FinRL-Library")
from finrl.model.models import DRLAgent

# %%
os.chdir("/Users/a16643222/Documents/tensortrade/examples/tmp")
l = []
for file in glob.glob("*result3_*.pkl"):
    df = pd.read_pickle(file)
    df.net_worth.plot()
    plt.show()
    l += [df['net_worth'][df.shape[0]-1] - df['net_worth'][0]]

a = 73000
np.mean(l)/a * 100, np.std(l)/a * 100, len(l)/a * 100, np.mean(l), np.std(l), len(l)
# Out:
# (-0.09588249093473379,
#  0.9820020340187338,
#  0.04657534246575343,
#  -69.99421838235567,
#  716.8614848336756,
#  34)

# %%
df
# Out:
#          net_worth
# 0          73000.0
# 1      72933.36955
# 2       72936.2375
# 3       72917.8656
# 4      72881.83335
# ...            ...
# 1258    72540.9696
# 1259  72543.355075
# 1260  72543.355075
# 1261   72593.45005
# 1262  72586.293625
#
# [1263 rows x 1 columns]
